# %%
df_cars.to_csv("../data/processed/car_data_cleaned.csv", index=False)
print("Saved cleaned data to data/processed/car_data_cleaned.csv")
# Out:
# Saved cleaned data to data/processed/car_data_cleaned.csv

# %%
print(df_cars['Car_Name'].value_counts())
# Out:
# Car_Name
# city             26
# corolla altis    16
# verna            14
# fortuner         10
# brio             10
# ciaz              9
# i20               9
# innova            9
# grand i10         8
# amaze             7
# jazz              7
# eon               6
# sx4               6
# alto k10          5
# i10               5
# swift             5
# ertiga            5
# wagon r           4
# ritz              4
# dzire             4
# etios liva        4
# etios cross       3
# xcent             3
# creta             3
# etios g           3
# elantra           2
# alto 800          1
# 800               1
# s cross           1
# omni              1
# baleno            1
# ignis             1
# vitara brezza     1
# corolla           1
# etios gd          1
# camry             1
# land cruiser      1
# Name: count, dtype: int64

# %%
print("Duplicates before:", df_cars.duplicated().sum())
df_cars = df_cars.drop_duplicates().reset_index(drop=True)
print("Shape after removing duplicates:", df_cars.shape)
# Out:
# Duplicates before: 2
# Shape after removing duplicates: (198, 9)

# %%
df_cars = df[~df['Car_Name'].isin(motorcycle_names)].reset_index(drop=True)
print("Shape after filtering to cars only:", df_cars.shape)
df_cars.head()
# Out:
# Shape after filtering to cars only: (200, 9)
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
car_names = [n for n in df['Car_Name'].unique() if n not in motorcycle_names]
print("Number of unique car names:", len(car_names))
print(sorted(car_names))
# Out:
# Number of unique car names: 37
# ['800', 'alto 800', 'alto k10', 'amaze', 'baleno', 'brio', 'camry', 'ciaz', 'city', 'corolla', 'corolla altis', 'creta', 'dzire', 'elantra', 'eon', 'ertiga', 'etios cross', 'etios g', 'etios gd', 'etios liva', 'fortuner', 'grand i10', 'i10', 'i20', 'ignis', 'innova', 'jazz', 'land cruiser', 'omni', 'ritz', 's cross', 'swift', 'sx4', 'verna', 'vitara brezza', 'wagon r', 'xcent']

# %%
motorcycle_names = [
    'Activa 3g', 'Activa 4g', 'Bajaj  ct 100', 'Bajaj Avenger 150',
    'Bajaj Avenger 150 street', 'Bajaj Avenger 220', 'Bajaj Avenger 220 dtsi',
    'Bajaj Avenger Street 220', 'Bajaj Discover 100', 'Bajaj Discover 125',
    'Bajaj Dominar 400', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 135 LS',
    'Bajaj Pulsar 150', 'Bajaj Pulsar 220 F', 'Bajaj Pulsar NS 200',
    'Bajaj Pulsar RS200', 'Hero  CBZ Xtreme', 'Hero  Ignitor Disc',
    'Hero Extreme', 'Hero Glamour', 'Hero Honda CBZ extreme',
    'Hero Honda Passion Pro', 'Hero Hunk', 'Hero Passion Pro',
    'Hero Passion X pro', 'Hero Splender Plus', 'Hero Splender iSmart',
    'Hero Super Splendor', 'Honda Activa 125', 'Honda Activa 4G',
    'Honda CB Hornet 160R', 'Honda CB Shine', 'Honda CB Trigger',
    'Honda CB Unicorn', 'Honda CB twister', 'Honda CBR 150',
    'Honda Dream Yuga ', 'Honda Karizma', 'Hyosung GT250R', 'KTM 390 Duke ',
    'KTM RC200', 'KTM RC390', 'Mahindra Mojo XT300', 'Royal Enfield Bullet 350',
    'Royal Enfield Classic 350', 'Royal Enfield Classic 500',
    'Royal Enfield Thunder 350', 'Royal Enfield Thunder 500',
    'Suzuki Access 125', 'TVS Apache RTR 160', 'TVS Apache RTR 180',
    'TVS Jupyter', 'TVS Sport ', 'TVS Wego', 'UM Renegade Mojave',
    'Yamaha FZ  v 2.0', 'Yamaha FZ 16', 'Yamaha FZ S ', 'Yamaha FZ S V 2.0',
    'Yamaha Fazer '
]

print("Number of motorcycle names:", len(motorcycle_names))

# Check how many rows this actually affects
bike_rows = df[df['Car_Name'].isin(motorcycle_names)]
print("Number of motorcycle rows in dataset:", len(bike_rows))
print("Number of car rows remaining:", len(df) - len(bike_rows))
# Out:
# Number of motorcycle names: 61
# Number of motorcycle rows in dataset: 101
# Number of car rows remaining: 200

# %%
with open('../data/raw/unique_car_names.txt', 'w') as f:
    for name in sorted(df['Car_Name'].unique()):
        f.write(name + '\n')
print("Saved to unique_car_names.txt")
# Out:
# Saved to unique_car_names.txt

# %%
unique_names = sorted(df['Car_Name'].unique())
print("Total unique names:", len(unique_names))
# Out:
# Total unique names: 98

# %%
# List all unique Car_Name values, sorted, so we can visually identify the pattern
for name in sorted(df['Car_Name'].unique()):
    print(name)
# Out:
# 800
# Activa 3g
# Activa 4g
# Bajaj  ct 100
# Bajaj Avenger 150
# Bajaj Avenger 150 street
# Bajaj Avenger 220
# Bajaj Avenger 220 dtsi
# Bajaj Avenger Street 220
# Bajaj Discover 100
# Bajaj Discover 125
# Bajaj Dominar 400
# Bajaj Pulsar  NS 200
# Bajaj Pulsar 135 LS
# Bajaj Pulsar 150
# Bajaj Pulsar 220 F
# Bajaj Pulsar NS 200
# Bajaj Pulsar RS200
# Hero  CBZ Xtreme
# Hero  Ignitor Disc
# Hero Extreme
# Hero Glamour
# Hero Honda CBZ extreme
# Hero Honda Passion Pro
# Hero Hunk
# Hero Passion Pro
# Hero Passion X pro
# Hero Splender Plus
# Hero Splender iSmart
# Hero Super Splendor
# Honda Activa 125
# Honda Activa 4G
# Honda CB Hornet 160R
# Honda CB Shine
# Honda CB Trigger
# Honda CB Unicorn
# Honda CB twister
# Honda CBR 150
# Honda Dream Yuga
# Honda Karizma
# Hyosung GT250R
# KTM 390 Duke
# KTM RC200
# KTM RC390
# Mahindra Mojo XT300
# Royal Enfield Bullet 350
# Royal Enfield Classic 350
# Royal Enfield Classic 500
# Royal Enfield Thunder 350
# Royal Enfield Thunder 500
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 15    ertiga  2016           7.75          10.79       43000    Diesel
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 51  fortuner  2015          23.00          30.61       40000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Selling_type Transmission  Owner
# 15       Dealer       Manual      0
# 17       Dealer       Manual      0
# 51       Dealer    Automatic      0
# 93       Dealer    Automatic      0

# %%
df.sort_values('Present_Price').head(20)[['Car_Name', 'Present_Price', 'Selling_Price']]
# Out:
#                    Car_Name  Present_Price  Selling_Price
# 195           Bajaj  ct 100           0.32           0.18
# 183      Bajaj Discover 100           0.47           0.27
# 181      Hero Splender Plus           0.48           0.30
# 173               Activa 4g           0.51           0.40
# 180  Hero Honda Passion Pro           0.51           0.30
# 187        Honda CB twister           0.51           0.25
# 197        Honda CB twister           0.51           0.16
# 155         Honda Activa 4G           0.51           0.48
# 159         Honda Activa 4G           0.51           0.45
# 196               Activa 3g           0.52           0.17
# 186                TVS Wego           0.52           0.25
# 178             TVS Jupyter           0.52           0.35
# 156              TVS Sport            0.52           0.48
# 158       Honda Dream Yuga            0.54           0.48
# 169    Hero Splender iSmart           0.54           0.40
# ...

# %%
print("Missing values per column:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())

print("\nFuel_Type unique values:", df['Fuel_Type'].unique())
print("Selling_type unique values:", df['Selling_type'].unique())
print("Transmission unique values:", df['Transmission'].unique())
print("Owner unique values:", df['Owner'].unique())

print("\nYear range:", df['Year'].min(), "to", df['Year'].max())
# Out:
# Missing values per column:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64
#
# Duplicate rows: 2
#
# Fuel_Type unique values: ['Petrol' 'Diesel' 'CNG']
# Selling_type unique values: ['Dealer' 'Individual']
# Transmission unique values: ['Manual' 'Automatic']
# Owner unique values: [0 1 3]
#
# Year range: 2003 to 2018

# %%
import pandas as pd

df = pd.read_csv("../data/raw/car data.csv")

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)
df.head()
# Out:
# Shape: (301, 9)
#
# Columns: ['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type', 'Transmission', 'Owner']
#
# Data types:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# ...
